# %%
a=99
while a>1:
    print( str(a)+' бутылок пива на стене\n'+str(a)+' бутылок пива!\nВозьми одну, пусти по кругу\n'+str(a-1)+' бутылок пива на стене!')
    a=a-1
    if a==1:
        print('Нет бутылок пива на стене!\nНет бутылок пива!\nПойди в магазин и купи ещё,\n99 бутылок пива на стене!')
# Out:
# 99 бутылок пива на стене
# 99 бутылок пива!
# Возьми одну, пусти по кругу
# 98 бутылок пива на стене!
# 98 бутылок пива на стене
# 98 бутылок пива!
# Возьми одну, пусти по кругу
# 97 бутылок пива на стене!
# 97 бутылок пива на стене
# 97 бутылок пива!
# Возьми одну, пусти по кругу
# 96 бутылок пива на стене!
# 96 бутылок пива на стене
# 96 бутылок пива!
# Возьми одну, пусти по кругу
# 95 бутылок пива на стене!
# 95 бутылок пива на стене
# 95 бутылок пива!
# Возьми одну, пусти по кругу
# 94 бутылок пива на стене!
# 94 бутылок пива на стене
# 94 бутылок пива!
# Возьми одну, пусти по кругу
# 93 бутылок пива на стене!
# 93 бутылок пива на стене
# 93 бутылок пива!
# Возьми одну, пусти по кругу
# 92 бутылок пива на стене!
# 92 бутылок пива на стене
# 92 бутылок пива!
# Возьми одну, пусти по кругу
# 91 бутылок пива на стене!
# 91 бутылок пива на стене
# 91 бутылок пива!
# Возьми одну, пусти по кругу
# 90 бутылок пива на стене!
# 90 бутылок пива на стене
# 90 бутылок пива!
# ...

# %%
for a in range(1, 101):
    if a%3==0 and a%5==0:
        print("FizzBuzz")
    elif a%3==0:
        print("Fizz")
    elif a%5==0:
        print("Buzz")
    else:
        print(a)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
